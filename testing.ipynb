# %%
#testing one_hot_encode from data_loader.py
from data_loader import one_hot_encode
matrix = one_hot_encode(np.array([0,0,0,0]), 10)
print(matrix)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 #testing one_hot_encode from main.py
# ----> 2 from main import one_hot_encode
#       3 matrix = one_hot_encode(np.array([0,0,0,0]), 10)
#       4 print(matrix)
#
# ImportError: cannot import name 'one_hot_encode' from 'main' (/Users/aj/Desktop/GitHub/Neurales_Netz_EF/main.py)
